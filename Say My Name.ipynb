# %%
# Dependencies and Setup
from bs4 import BeautifulSoup as bs
from splinter import Browser
from datetime import datetime
import json
import pandas as pd
import time
import numpy as np
import os
import glob
import pprint

# %%
# WINDOWS/PC - Import splinter and set the cromedriver path
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# MAC - Import splinter and set the cromedriver path
#executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
#browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# # Load and Convert Baby Names and Year of Birth

# %%
# load and read name files; add year column based on file name

fileList=glob.glob("Baby Names/*.txt")

#print(fileList)
#def addField(fileList):
for filename in fileList:
    #print(filename)
    df=pd.read_csv(filename, header=None)           
    df['yr']=[filename.rsplit("b",1)[1]]*df.shape[0]
    #print(df['yr'])
    df.to_csv(filename+".csv", index=None, header=None)

# %%
# Add Column Headings, Concatenate files and merge to single csv file "Concatenated.csv"

outfile="BabyNames.csv"
fileList=glob.glob("Baby Names/*.csv")
dfList=[] # create an empty list
colnames=['Name', 'Gender', 'Count', 'Year']

for filename in fileList:
    print(filename)
    df=pd.read_csv(filename, header=None)
    dfList.append(df)
    
concatDf=pd.concat(dfList, axis=0)
concatDf.columns=colnames

# %%
# Sample output from the "Concatenated.csv" file
concatDf.head()

# %%
# CODE for splitting .txt from Year field - Leaving only the year
newYr = concatDf["Year"].str.split(".",n=1, expand=True)
#newYr.head()
concatDf["Year"]=newYr[0]
concatDf["txt"]=newYr[1]
concatDf.drop(columns=['txt'], inplace=True)
concatDf.head()

# %%
concatDf.tail()

# %%
# Pass dataframe to a .csv file

concatDf.to_csv(outfile, index=None)
# len(concatDf)

# %% [markdown]
# # LOAD and CONATENATE BABY NAMES with States

# %%
# For State files Add Column Headings, Concatenate files and merge to single csv file "Concatenated.csv"

outfile="BabyNames_States.csv"
fileList=glob.glob("Baby Names with States/*.txt")
dfList=[] # create an empty list
colnames=['State','Gender', 'Year', 'Name', 'Count']

for filename in fileList:
    #print(filename)
    df=pd.read_csv(filename, header=None)
    dfList.append(df)

StatesDF=pd.concat(dfList, axis=0)
StatesDF.columns=colnames
StatesDF.head()
# Out:
#   State Gender  Year      Name  Count
# 0    AK      F  1910      Mary     14
# 1    AK      F  1910     Annie     12
# 2    AK      F  1910      Anna     10
# 3    AK      F  1910  Margaret      8
# 4    AK      F  1910     Helen      7

# %%
# Export dataframe to "characters.csv" file
StatesDF.to_csv("BabyNames_States.csv", index=True, header=True)

# %% [markdown]
# # Load and Convert Movie .csv Files

# %%
# Insert Movies Data from csv file and convert 'release_date' to 'year' field and add to dataframe
moviesDF=pd.read_csv('Cleaned_tmdb_5000_movies.csv')
moviesDF['release_date'] = pd.to_datetime(moviesDF['release_date'])
objDate = moviesDF['release_date'].dt.year
year = objDate.apply(int)
#year
moviesDF['year'] = year
moviesDF.head()
# Out:
#      budget                                             genres  \
# 0   4000000  [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# 1  11000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 2  94000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 3  55000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4  15000000                      [{"id": 18, "name": "Drama"}]
#
#                                             homepage  id  \
# 0                                                NaN   5
# 1  http://www.starwars.com/films/star-wars-episod...  11
# 2              http://movies.disney.com/finding-nemo  12
# 3                                                NaN  13
# 4                      http://www.dreamworks.com/ab/  14
#
#                                             keywords original_language  \
# 0  [{"id": 612, "name": "hotel"}, {"id": 613, "na...                en
# 1  [{"id": 803, "name": "android"}, {"id": 4270, ...                en
# ...

# %%
# Export dataframe to "movies.csv" file
moviesDF.to_csv("movies.csv", index=True, header=True)

# %%
# Optional code for conversion of json formatted columns
json_columns = ['genres', 'keywords', 'production_countries', 'production_companies', 'spoken_languages']
#for column in json_columns:
    #df[column] = df[column].apply(json.loads)
    #moviesDF[column] = moviesDF[column].apply(json.loads)

# %% [markdown]
# # Load and Convert Credits.csv to Characters.csv Files

# %%
# Insert Credits Data from csv file
credits="Cleaned_tmdb_5000_credits.csv"
creditsDF=pd.read_csv(credits)
creditsDF.drop(columns=['crew'], inplace=True)
creditsDF.head()
# Out:
#    movie_id            title  \
# 0       5.0       Four Rooms
# 1      11.0        Star Wars
# 2      12.0     Finding Nemo
# 3      13.0     Forrest Gump
# 4      14.0  American Beauty
#
#                                                 cast
# 0  [{"cast_id": 42, "character": "Ted the Bellhop...
# 1  [{"cast_id": 3, "character": "Luke Skywalker",...
# 2  [{"cast_id": 8, "character": "Marlin (voice)",...
# 3  [{"cast_id": 7, "character": "Forrest Gump", "...
# 4  [{"cast_id": 6, "character": "Lester Burnham",...

# %%
# Convert 'cast' list of dictionaries in JSON to a dataframe; Loop through all of the dictionaries and append to the dataframe.
# Add the movie_id for each record and Drop the 'credit_id' field

counter = 0 
#print(type(creditsDF))
character_df = pd.DataFrame(columns=['cast_id', 'character', 'gender', 'id', 'name', 'order', 'movie_id', 'title'])
for row in creditsDF.iterrows():     
    counter = counter + 1
    #print(counter)                                 #Keep to show counter for debugging
    castListDF = row[1][2]
    #print(row)                                     #Keep to print each row for debugging
    try:
        ch_data = json.loads(castListDF)
    except Exception as e:
        print(counter)
        print(row)
        print('Sorry, information not available')
        pass 
    ch_df = pd.DataFrame(ch_data)                   #Builds a new dataframe for each movie "ch_df" 
    ch_df['movie_id'] = row[1]['movie_id']          #Adds the movie id to each row in the "ch_df" dataframe
    ch_df['title'] = row[1]['title']                #Adds the movie title to each row in the dataframe
    ch_df.drop(columns=['credit_id'], inplace=True) #Drops the credit_id from the dataframe
    character_df=character_df.append(ch_df)         #Appends the new dataframe to the main "character_df"   
    #if counter >= 500:                             #Keep to break after short run for debugging
        #break
character_df.head()
# Out:
# 4009
# (4008, movie_id    NaN
# title       NaN
# cast        NaN
# Name: 4008, dtype: object)
# Sorry, information not available
#   cast_id        character gender    id              name order  movie_id  \
# 0      42  Ted the Bellhop      2  3129          Tim Roth     0       5.0
# 1      31              Man      2  3131  Antonio Banderas     1       5.0
# 2      29           Angela      1  3130    Jennifer Beals     2       5.0
# 3      25          Elspeth      1  3125           Madonna     3       5.0
# 4      41         Margaret      1  3141      Marisa Tomei     4       5.0
#
#         title
# 0  Four Rooms
# 1  Four Rooms
# 2  Four Rooms
# 3  Four Rooms
# 4  Four Rooms

# %%
character_df.tail()
# Out:
#   cast_id      character gender       id             name order  movie_id  \
# 1       4             BB      0  1734573      Kim Baldwin     2  433715.0
# 2       5          Sugar      0  1734574  Ariana Stephens     3  433715.0
# 3       6           Drew      0  1734575      Bryson Funk     4  433715.0
# 0      99  Not Available      0     1000          Unknown     0  447027.0
# 0       0       Narrator      0  1354401  Tony Oppedisano     1  459488.0
#
#                          title
# 1                       8 Days
# 2                       8 Days
# 3                       8 Days
# 0              Running Forever
# 0  To Be Frank, Sinatra at 100

# %%
# CODE for splitting ['character'] name to first name only
newName = character_df["character"].str.split(" ",n=2, expand=True)
#newName.head()
character_df["First"]=newName[0]
character_df["Second"]=newName[1]
character_df["Third"]=newName[2]
#concatDf.drop(columns=['Second'], inplace=True)
character_df.head()
# Out:
#   cast_id        character gender    id              name order  movie_id  \
# 0      42  Ted the Bellhop      2  3129          Tim Roth     0       5.0
# 1      31              Man      2  3131  Antonio Banderas     1       5.0
# 2      29           Angela      1  3130    Jennifer Beals     2       5.0
# 3      25          Elspeth      1  3125           Madonna     3       5.0
# 4      41         Margaret      1  3141      Marisa Tomei     4       5.0
#
#         title     First Second    Third
# 0  Four Rooms       Ted    the  Bellhop
# 1  Four Rooms       Man   None     None
# 2  Four Rooms    Angela   None     None
# 3  Four Rooms   Elspeth   None     None
# 4  Four Rooms  Margaret   None     None

# %%
# CODE for splitting ['actor'] name to first name only
newActorName = character_df["name"].str.split(" ",n=1, expand=True)
#newActorName.head()
character_df["Actor_FirstName"]=newActorName[0]
character_df["Actor_LastName"]=newActorName[1]
character_df.head()
# Out:
#   cast_id        character gender    id              name order  movie_id  \
# 0      42  Ted the Bellhop      2  3129          Tim Roth     0       5.0
# 1      31              Man      2  3131  Antonio Banderas     1       5.0
# 2      29           Angela      1  3130    Jennifer Beals     2       5.0
# 3      25          Elspeth      1  3125           Madonna     3       5.0
# 4      41         Margaret      1  3141      Marisa Tomei     4       5.0
#
#         title Actor_FirstName Actor_LastName
# 0  Four Rooms             Tim           Roth
# 1  Four Rooms         Antonio       Banderas
# 2  Four Rooms        Jennifer          Beals
# 3  Four Rooms         Madonna           None
# 4  Four Rooms          Marisa          Tomei

# %%
# Export dataframe to "characters.csv" file
character_df.drop(columns=['cast_id', 'character', 'id', 'name', 'order'], inplace=True)
character_df.head()
# Out:
#   gender  movie_id       title     First Second    Third Actor_FirstName  \
# 0      2       5.0  Four Rooms       Ted    the  Bellhop             Tim
# 1      2       5.0  Four Rooms       Man   None     None         Antonio
# 2      1       5.0  Four Rooms    Angela   None     None        Jennifer
# 3      1       5.0  Four Rooms   Elspeth   None     None         Madonna
# 4      1       5.0  Four Rooms  Margaret   None     None          Marisa
#
#   Actor_LastName
# 0           Roth
# 1       Banderas
# 2          Beals
# 3           None
# 4          Tomei

# %%
# Add Movie Year to Character Dataframe
movies_df = moviesDF.drop(columns=['budget', 'title','production_countries','homepage', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'runtime', 'spoken_languages', 'tagline', 'vote_count'])
movies_df.head()
# Out:
#                                               genres  id release_date  \
# 0  [{"id": 80, "name": "Crime"}, {"id": 35, "name...   5   1995-12-09
# 1  [{"id": 12, "name": "Adventure"}, {"id": 28, "...  11   1977-05-25
# 2  [{"id": 16, "name": "Animation"}, {"id": 10751...  12   2003-05-30
# 3  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  13   1994-07-06
# 4                      [{"id": 18, "name": "Drama"}]  14   1999-09-15
#
#      revenue    status  vote_average  year
# 0    4300000  Released           6.5  1995
# 1  775398007  Released           8.1  1977
# 2  940335536  Released           7.6  2003
# 3  677945399  Released           8.2  1994
# 4  356296601  Released           7.9  1999

# %%
movies_characters = pd.merge(movies_df, character_df, left_on="id", right_on="movie_id")
movies_characters = movies_characters.drop(columns=['id'])
movies_characters.head()
# Out:
#                                               genres release_date  revenue  \
# 0  [{"id": 80, "name": "Crime"}, {"id": 35, "name...   1995-12-09  4300000
# 1  [{"id": 80, "name": "Crime"}, {"id": 35, "name...   1995-12-09  4300000
# 2  [{"id": 80, "name": "Crime"}, {"id": 35, "name...   1995-12-09  4300000
# 3  [{"id": 80, "name": "Crime"}, {"id": 35, "name...   1995-12-09  4300000
# 4  [{"id": 80, "name": "Crime"}, {"id": 35, "name...   1995-12-09  4300000
#
#      status  vote_average  year gender  movie_id       title     First Second  \
# 0  Released           6.5  1995      2       5.0  Four Rooms       Ted    the
# 1  Released           6.5  1995      2       5.0  Four Rooms       Man   None
# 2  Released           6.5  1995      1       5.0  Four Rooms    Angela   None
# 3  Released           6.5  1995      1       5.0  Four Rooms   Elspeth   None
# 4  Released           6.5  1995      1       5.0  Four Rooms  Margaret   None
#
#      Third Actor_FirstName Actor_LastName
# ...

# %%
movies_characters.tail()
# Out:
#                                                    genres release_date  \
# 106256  [{"id": 53, "name": "Thriller"}, {"id": 18, "n...   2014-06-15
# 106257  [{"id": 53, "name": "Thriller"}, {"id": 18, "n...   2014-06-15
# 106258  [{"id": 53, "name": "Thriller"}, {"id": 18, "n...   2014-06-15
# 106259                  [{"id": 10751, "name": "Family"}]   2015-10-27
# 106260                [{"id": 99, "name": "Documentary"}]   2015-12-12
#
#         revenue    status  vote_average  year gender  movie_id  \
# 106256        0  Released           0.0  2014      0  433715.0
# 106257        0  Released           0.0  2014      0  433715.0
# 106258        0  Released           0.0  2014      0  433715.0
# 106259        0  Released           0.0  2015      0  447027.0
# 106260        0  Released           0.0  2015      0  459488.0
#
#                               title     First     Second Third  \
# 106256                       8 Days        BB       None  None
# ...

# %%
# Export character_df to newCharacters.csv file
movies_characters.to_csv("new_movies_characters.csv", index=True, header=True)

# %% [markdown]
# # LOADING TO SQLite

# %%
# SQL Alchemy
from sqlalchemy import create_engine                    #Allows SQLAlchemy to create connections to SQL databases
from sqlalchemy.ext.declarative import declarative_base #Allows SQLAlchemy to convert the classes created in Python to SQL tables
from sqlalchemy import Column, Integer, String, Float   #Allows us to declare column types
Base = declarative_base()

# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()

# Set path
#import sys
#sys.path.append('../../../../..')

# Config variables and Connect to Local MySQL Database
from config import local_gwsis_dbname, local_gwsis_dbuser, local_gwsis_dbpwd          # For Local MySQL db

#Connect to AWS Cloud Database
#from config import remote_db_endpoint, remote_db_port                                #For AWS Cloud Connection
#from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd      #For AWS Cloud Connection

#Import Pandas
#import pandas as pd                                                                  #This was done earlier in cell #1

# %%
# Create Database Connection - Supply the connection string to connect to the database
# If using MySQL, create the 'saymyname' database first in Workbench                            
# This project uses SQLite

engine = create_engine('sqlite:///saymyname.sqlite')
conn = engine.connect()

#For AWS Cloud Connection
#engine = create_engine(f"mysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")
# CHANGE THIS endpoint to: saymyname.cypd6auw3ehl.us-east-2.rds.amazonaws.com          #This is my personal AWS Hostname

# %%
# Create a "Metadata" Layer that Abstracts our SQL Database

Base.metadata.create_all(engine)

# Use this to clear out the db
# Base.metadata.drop_all(engine)

# %%
#Create a Session Object to Connect to DB

from sqlalchemy.orm import Session
session = Session(bind=engine)

# %% [markdown]
# # Post Tables to SQLite DB

# %%
names_df = pd.read_csv("Concatenated.csv")
names_load = names_df
names_load.to_sql(name='names', if_exists='replace', con=conn, chunksize=2000000, index=False)

# %%
#movies_df = pd.read_csv("Cleaned_tmdb_5000_movies.csv")
#movies_load = movies_df
moviesDF.to_sql(name='movies', if_exists='replace', con=conn, chunksize=2000000, index=False)

# %%
#characters_df = pd.read_csv("Cleaned_tmdb_5000_credits.csv")
#character_load = character_df
character_df.to_sql(name='characters', if_exists='replace', con=conn, chunksize=2000000, index=False)

# %%
#OPTIONAL Code for Working with tables already imported in a SQL database
#print(engine.table_names())
  # sample output ['movies', 'characters', 'concatenated_names']

# To access the tables with Python use "Reflection". Reflection reads database and builds SQLAlchemy Table objects to use in our code
# Import the metadata and table objects needed for reflection
#from sqlalchemy import MetaData, Table

# Initialize the metadata object
#metadata = MetaData()

#table_name = Table('table_name', metadata, autoload=True, autoload_with=engine)

#print(repr(table_name))

# %% [markdown]
# # Posting to AWS Cloud

# %%
from config import remote_db_endpoint, remote_db_port, remote_dbname, remote_dbuser, remote_dbpwd 

# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# AWS Database Connection
engine = create_engine(f"mysql://{remote_dbuser}:{remote_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_dbname}")

# Create a remote database engine connection
conn = engine.connect()

# %%
#babynames_df = pd.read_csv("BabyNames.csv")
babynames_df.to_sql(name='baby_names', if_exists='append', con=conn, chunksize=5000, index=False)

# %%
StatesDF.to_sql(name='baby_names_by_state', if_exists='append', con=conn, chunksize=10000, index=False)

# %%
baby_names_sql = pd.read_sql('select * from baby_names_by_state limit 50000', con=conn)

# %%
baby_names_sql
# Out:
#       State Gender  Year       Name  Count
# 0        AK      F  1910       Mary     14
# 1        AK      F  1910      Annie     12
# 2        AK      F  1910       Anna     10
# 3        AK      F  1910   Margaret      8
# 4        AK      F  1910      Helen      7
# 5        AK      F  1910      Elsie      6
# 6        AK      F  1910       Lucy      6
# 7        AK      F  1910    Dorothy      5
# 8        AK      F  1911       Mary     12
# 9        AK      F  1911   Margaret      7
# 10       AK      F  1911       Ruth      7
# 11       AK      F  1911      Annie      6
# 12       AK      F  1911  Elizabeth      6
# 13       AK      F  1911      Helen      6
# 14       AK      F  1912       Mary      9
# 15       AK      F  1912      Elsie      8
# 16       AK      F  1912      Agnes      7
# 17       AK      F  1912       Anna      7
# 18       AK      F  1912      Helen      7
# 19       AK      F  1912     Louise      7
# 20       AK      F  1912       Jean      6
# ...

# %% [markdown]
# # Prepare Tables for Tableau Analysis

# %%
# Merge Movies and Characters Dataframe with Baby Names by State Dataframe
characters_babies = pd.merge(movies_characters, StatesDF, left_on="First", right_on="Name")
characters_babies = characters_babies.drop(columns=['genres', 'release_date', 'revenue', 'status', 'vote_average', 'movie_id', 'title', 'Second', 'Third', 'Actor_LastName', 'State'])
characters_babies.head()
# Out:
#    year gender First Actor_FirstName Gender  Year Name  Count
# 0  1995      2   Ted             Tim      M  1957  Ted      5
# 1  1995      2   Ted             Tim      M  1960  Ted      5
# 2  1995      2   Ted             Tim      M  1969  Ted      6
# 3  1995      2   Ted             Tim      M  1911  Ted      7
# 4  1995      2   Ted             Tim      M  1913  Ted      9

# %%
characters_babies.tail()
# Out:
#            year gender   First Actor_FirstName Gender  Year    Name  Count
# 128863132  2011      1  Imelda       Constance      F  1927  Imelda      6
# 128863133  2011      1  Imelda       Constance      F  1930  Imelda      5
# 128863134  2011      1  Imelda       Constance      F  1935  Imelda      5
# 128863135  2017      1  Nalini          Poorna      F  2013  Nalini      6
# 128863136  2017      1  Nalini          Poorna      F  2003  Nalini      5

# %%
# Code to Count the Popularity of Character Names by Year Movie was Released
characters_babies_df=characters_babies.groupby(['year', 'First']).size().to_frame('size').reset_index().sort_values(['year', 'size'], ascending=[True, False])
characters_babies_df.head()
# Out:
#     year       First   size
# 18  1916        Mary  13024
# 6   1916     Charles   6420
# 5   1916   Catherine   5316
# 0   1916      Arthur   5068
# 17  1916  Marguerite   2503

# %%
# Export dataframe to "characters.csv" file
characters_babies_df.to_csv("Characters_Babies.csv", index=True, header=True)

# %%
# Code to Count the Popularity of Actor Names by Year Movie was Released
ab_temp = character_df[['Actor_FirstName']]
actors_babies = pd.merge(ab_temp, StatesDF, left_on="Actor_FirstName", right_on="Name")
#actors_babies = actors_babies.drop(columns=['Gender', 'State'])
actors_babies.head()
# Out:
#   Actor_FirstName State Gender  Year Name  Count
# 0             Tim    AK      M  1958  Tim      5
# 1             Tim    AK      M  1959  Tim     19
# 2             Tim    AK      M  1960  Tim     10
# 3             Tim    AK      M  1961  Tim      5
# 4             Tim    AK      M  1962  Tim     11

# %%
# Code to Count the Popularity of Actor Names by Year Movie was Released
actors_babies_df=actors_babies.groupby(['Year', 'Actor_FirstName']).size().to_frame('size').reset_index().sort_values(['Year', 'size'], ascending=[True, False])
actors_babies_df.head()
# Out:
#      Year Actor_FirstName    size
# 573  1910            John  110330
# 260  1910           David   64801
# 538  1910           James   58084
# 936  1910          Robert   52530
# 932  1910         Richard   38732

# %%
# Export dataframe to "characters.csv" file
actors_babies_df.to_csv("Actors_Babies.csv", index=True, header=True)

# %% [markdown]
# End of Code
